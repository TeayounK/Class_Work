# %%
from matplotlib.rcsetup import partial
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# Problem 1

curr_sum = 0 
partial_sums = [] 
for n in range(0,50): 
  curr_sum += 1/2**n  
  partial_sums.append(curr_sum) 
print(partial_sums[-1])

plt.plot(partial_sums)
plt.plot(np.linspace(0,k),np.linspace(2,2), "--", color = "red")
plt.show()
# Out:
# 1.9999999999999982

# %%
#Problem 2

curr_sum = 0
partial_sums_list = []

for n in range(0,50):
  curr_sum += (-1)**n
  partial_sums_list.append(curr_sum)
print(partial_sums_list[-1])

plt.plot(partial_sums_list)
plt.show()

# This series diverges.
# Out:
# 0

# %%
# Problem 3

curr_sum = 0
part_sum_list = []
k = 50

for n in range(1,k):
  curr_sum += 1/n
  part_sum_list.append(curr_sum)
print(part_sum_list[-1])

plt.plot(part_sum_list)
plt.show()
# Out:
# 4.4792053383294235

# %%
# Problem 3 continues

curr_sum = 0
part_sum_list = []
k = 100

for n in range(1,k):
  curr_sum += 1/n
  part_sum_list.append(curr_sum)
print(part_sum_list[-1])

plt.plot(part_sum_list)
plt.show()
# Out:
# 5.177377517639621

# %%
# Problem 3 continues

curr_sum = 0
part_sum_list = []
k = 1000

for n in range(1,k):
  curr_sum += 1/n
  part_sum_list.append(curr_sum)
print(part_sum_list[-1])

plt.plot(part_sum_list)
plt.show()


# This series diverges
# Out:
# 7.484470860550343

# %%
# Problem 4

curr_sum = 0
part_sum_list = []
k = 100000

for n in range(1,k):
  curr_sum += 1/(n*(math.log(n+1)))
  part_sum_list.append(curr_sum)
print(part_sum_list[-1])

plt.plot(part_sum_list)
plt.plot(np.linspace(0,k),np.linspace(4,4), "--", color = "red")
plt.ylim(0,5)
plt.show()

# This series diverges.
# The limit of the series is 4
# Out:
# 4.285002919508644

# %%
# Problem 5

curr_sum = -1/math.sqrt(3)
part_sum_list = []
k = 10000   #terms

for n in range(2,k):
  curr_sum += (-1)**n * np.floor(math.log2(n))/n
  part_sum_list.append(curr_sum)
print(part_sum_list[-1])

plt.plot(part_sum_list)
plt.plot(np.linspace(0,k),np.linspace(-0.00084567318610623,-0.00084567318610623), "--", color = "red")
plt.show()

#This series converges.
#The limit of the sequence of the partial sums is -0.00084567318610623.

#### Is it right??
# Out:
# -0.00084567318610623
